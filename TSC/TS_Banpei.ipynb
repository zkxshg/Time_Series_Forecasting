# %%
import banpei

# %%
import pandas as pd
raw_data = pd.read_csv('./data/periodic_wave.csv')
data = raw_data['y']

# %%
raw_data
# Out:
#               x         y
# 0      0.000000  0.065061
# 1      0.062958  0.047297
# 2      0.125916  0.112022
# 3      0.188873  0.280898
# 4      0.251831  0.217034
# ...         ...       ...
# 1495  93.995949 -0.287772
# 1496  94.058906 -0.218885
# 1497  94.121864 -0.133116
# 1498  94.184822 -0.132917
# 1499  94.247780 -0.065053
#
# [1500 rows x 2 columns]

# %%
data
# Out:
# 0       0.065061
# 1       0.047297
# 2       0.112022
# 3       0.280898
# 4       0.217034
#           ...
# 1495   -0.287772
# 1496   -0.218885
# 1497   -0.133116
# 1498   -0.132917
# 1499   -0.065053
# Name: y, Length: 1500, dtype: float64

# %%
model   = banpei.SST(w=50)
results = model.detect(data)

# %%
results
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
results = model.detect(data, is_lanczos=True)

# %%
results
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
from ggplot import *

# %%
ggplot(aes(x="x", y="y"), data=raw_data) + geom_point() + geom_line(color = 'blue')
# Out:
# <ggplot: (-9223371870461266376)>

# %%
raw_data.index
# Out:
# RangeIndex(start=0, stop=1500, step=1)
